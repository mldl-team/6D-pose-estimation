# %%
from ultralytics import YOLO
import os
import cv2

YOLO_MODEL = 'checkpoints/model_main.pt' 
LINEMOD_ROOT = 'dataset/Linemod_preprocessed/data/' 
OUTPUT_CROP_FOLDER = 'Phase3_RGB_Crops' 
CROP_SIZE = (224, 224)  # Resize all crops to this size
CLASS_IDS = [f"{i:02d}" for i in range(1, 14)]  # '01' to '13'
# ===========================================

# 🔹 Create output directory
os.makedirs(OUTPUT_CROP_FOLDER, exist_ok=True)

# 🔹 Load YOLOv8 model
model = YOLO(YOLO_MODEL)

# 🔁 Loop over each class folder (01 to 13)
for cls_id in CLASS_IDS:
    class_path = os.path.join(LINEMOD_ROOT, cls_id)
    
    # Skip missing folders like '03' and '07'
    if not os.path.isdir(class_path):
        print(f"[SKIPPED] Class folder does not exist: {class_path}")
        continue

    class_path = os.path.join(LINEMOD_ROOT, cls_id)
    rgb_folder = os.path.join(class_path, 'rgb')
    train_file = os.path.join(class_path, 'train.txt')  

    # 🔸 Read training image IDs
    with open(train_file, 'r') as f:
        image_ids = [line.strip() for line in f.readlines() if line.strip()]

    print(f"[{cls_id}] Processing {len(image_ids)} training images.")

    for img_id in image_ids:
        img_path = os.path.join(rgb_folder, f"{img_id}.png")

        # Load image
        img = cv2.imread(img_path)
        if img is None:
            print(f"[WARNING] Could not read image: {img_path}")
            continue

        # 🔍 Run YOLOv8 inference
        results = model(img)

        for det_idx, det in enumerate(results[0].boxes):
            # Get bounding box coordinates
            x1, y1, x2, y2 = map(int, det.xyxy[0].tolist())

            # Clamp to image dimensions
            x1, y1 = max(0, x1), max(0, y1)
            x2, y2 = min(img.shape[1], x2), min(img.shape[0], y2)

            # 🖼️ Crop the object
            cropped = img[y1:y2, x1:x2]

            # Resize for pose regressor
            cropped_resized = cv2.resize(cropped, CROP_SIZE)

            # Save crop with class and image ID in filename
            filename = f"cls{cls_id}_img{img_id}_det{det_idx}.png"
            save_path = os.path.join(OUTPUT_CROP_FOLDER, filename)
            cv2.imwrite(save_path, cropped_resized)

            print(f"✅ Saved: {filename}")

print("✅ All YOLOv8 crops saved for all classes.")
# Out:
# [01] Processing 186 training images.
#
# 0: 480x640 1 ape, 66.3ms
# Speed: 2.4ms preprocess, 66.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0004_det0.png
#
# 0: 480x640 1 ape, 37.1ms
# Speed: 2.9ms preprocess, 37.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0009_det0.png
#
# 0: 480x640 1 ape, 7.9ms
# Speed: 1.7ms preprocess, 7.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0021_det0.png
#
# 0: 480x640 1 ape, 8.6ms
# Speed: 1.8ms preprocess, 8.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0030_det0.png
#
# 0: 480x640 1 ape, 8.1ms
# Speed: 1.2ms preprocess, 8.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0044_det0.png
#
# 0: 480x640 1 ape, 8.0ms
# Speed: 1.4ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0048_det0.png
#
# 0: 480x640 1 ape, 18.1ms
# Speed: 2.0ms preprocess, 18.1ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0054_det0.png
#
# 0: 480x640 1 ape, 8.1ms
# Speed: 1.6ms preprocess, 8.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0068_det0.png
#
# 0: 480x640 1 ape, 8.2ms
# Speed: 1.4ms preprocess, 8.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0075_det0.png
#
# 0: 480x640 1 ape, 7.9ms
# Speed: 1.5ms preprocess, 7.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0079_det0.png
#
# 0: 480x640 1 ape, 7.8ms
# Speed: 1.9ms preprocess, 7.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0084_det0.png
#
# 0: 480x640 1 ape, 8.1ms
# Speed: 2.0ms preprocess, 8.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0093_det0.png
#
# 0: 480x640 1 ape, 7.8ms
# Speed: 1.9ms preprocess, 7.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0103_det0.png
#
# 0: 480x640 1 ape, 8.1ms
# Speed: 1.3ms preprocess, 8.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0111_det0.png
#
# 0: 480x640 1 ape, 8.3ms
# Speed: 1.4ms preprocess, 8.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0121_det0.png
#
# 0: 480x640 1 ape, 13.9ms
# Speed: 1.4ms preprocess, 13.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0126_det0.png
#
# 0: 480x640 1 ape, 8.5ms
# Speed: 1.3ms preprocess, 8.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0134_det0.png
#
# 0: 480x640 1 ape, 8.8ms
# Speed: 1.3ms preprocess, 8.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0138_det0.png
#
# 0: 480x640 1 ape, 13.1ms
# Speed: 1.6ms preprocess, 13.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0142_det0.png
#
# 0: 480x640 1 ape, 8.5ms
# Speed: 1.6ms preprocess, 8.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0151_det0.png
#
# 0: 480x640 1 ape, 8.5ms
# Speed: 1.5ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0158_det0.png
#
# 0: 480x640 1 ape, 8.2ms
# Speed: 1.3ms preprocess, 8.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0164_det0.png
#
# 0: 480x640 1 ape, 8.1ms
# Speed: 1.4ms preprocess, 8.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0172_det0.png
#
# 0: 480x640 1 ape, 8.0ms
# Speed: 1.6ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0174_det0.png
#
# 0: 480x640 1 ape, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0191_det0.png
#
# 0: 480x640 1 ape, 8.3ms
# Speed: 1.5ms preprocess, 8.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0198_det0.png
#
# 0: 480x640 1 ape, 8.5ms
# Speed: 1.7ms preprocess, 8.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0208_det0.png
#
# 0: 480x640 1 ape, 8.8ms
# Speed: 1.4ms preprocess, 8.8ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0210_det0.png
#
# 0: 480x640 1 ape, 8.0ms
# Speed: 1.7ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0211_det0.png
#
# 0: 480x640 1 ape, 8.0ms
# Speed: 1.2ms preprocess, 8.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0215_det0.png
#
# 0: 480x640 1 ape, 8.5ms
# Speed: 1.8ms preprocess, 8.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0217_det0.png
#
# 0: 480x640 1 ape, 25.3ms
# Speed: 1.8ms preprocess, 25.3ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0221_det0.png
#
# 0: 480x640 1 ape, 7.9ms
# Speed: 1.4ms preprocess, 7.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0226_det0.png
#
# 0: 480x640 1 ape, 1 benchvise, 8.3ms
# Speed: 1.3ms preprocess, 8.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0228_det0.png
# ✅ Saved: cls01_img0228_det1.png
#
# 0: 480x640 1 ape, 9.3ms
# Speed: 1.5ms preprocess, 9.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0232_det0.png
#
# 0: 480x640 1 ape, 8.5ms
# Speed: 1.7ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0242_det0.png
#
# 0: 480x640 1 ape, 8.7ms
# Speed: 1.4ms preprocess, 8.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0249_det0.png
#
# 0: 480x640 1 ape, 8.4ms
# Speed: 1.6ms preprocess, 8.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0267_det0.png
#
# 0: 480x640 1 ape, 10.1ms
# Speed: 1.8ms preprocess, 10.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0276_det0.png
#
# 0: 480x640 1 ape, 15.7ms
# Speed: 2.3ms preprocess, 15.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0278_det0.png
#
# 0: 480x640 1 ape, 28.2ms
# Speed: 1.6ms preprocess, 28.2ms inference, 6.4ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0279_det0.png
#
# 0: 480x640 1 ape, 19.3ms
# Speed: 1.9ms preprocess, 19.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0285_det0.png
#
# 0: 480x640 1 ape, 8.5ms
# Speed: 1.7ms preprocess, 8.5ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0288_det0.png
#
# 0: 480x640 1 ape, 15.1ms
# Speed: 1.3ms preprocess, 15.1ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0292_det0.png
#
# 0: 480x640 1 ape, 9.7ms
# Speed: 2.2ms preprocess, 9.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0299_det0.png
#
# 0: 480x640 1 ape, 8.9ms
# Speed: 2.0ms preprocess, 8.9ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0302_det0.png
#
# 0: 480x640 1 ape, 8.6ms
# Speed: 1.7ms preprocess, 8.6ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0307_det0.png
#
# 0: 480x640 1 ape, 9.6ms
# Speed: 1.5ms preprocess, 9.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0314_det0.png
#
# 0: 480x640 1 ape, 23.2ms
# Speed: 2.2ms preprocess, 23.2ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0321_det0.png
#
# 0: 480x640 1 ape, 8.7ms
# Speed: 1.4ms preprocess, 8.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0326_det0.png
#
# 0: 480x640 1 ape, 9.5ms
# Speed: 1.7ms preprocess, 9.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0330_det0.png
#
# 0: 480x640 1 ape, 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0337_det0.png
#
# 0: 480x640 1 ape, 9.1ms
# Speed: 2.4ms preprocess, 9.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0345_det0.png
#
# 0: 480x640 1 ape, 8.8ms
# Speed: 1.4ms preprocess, 8.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0353_det0.png
#
# 0: 480x640 1 ape, 8.8ms
# Speed: 1.7ms preprocess, 8.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0360_det0.png
#
# 0: 480x640 1 ape, 8.6ms
# Speed: 1.5ms preprocess, 8.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0380_det0.png
#
# 0: 480x640 1 ape, 25.3ms
# Speed: 1.5ms preprocess, 25.3ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0384_det0.png
#
# 0: 480x640 1 ape, 8.0ms
# Speed: 1.4ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0388_det0.png
#
# 0: 480x640 1 ape, 19.0ms
# Speed: 1.6ms preprocess, 19.0ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0390_det0.png
#
# 0: 480x640 1 ape, 8.0ms
# Speed: 1.5ms preprocess, 8.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0391_det0.png
#
# 0: 480x640 1 ape, 8.5ms
# Speed: 1.4ms preprocess, 8.5ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0395_det0.png
#
# 0: 480x640 1 ape, 9.9ms
# Speed: 1.4ms preprocess, 9.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0398_det0.png
#
# 0: 480x640 1 ape, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0402_det0.png
#
# 0: 480x640 1 ape, 14.7ms
# Speed: 1.5ms preprocess, 14.7ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0410_det0.png
#
# 0: 480x640 1 ape, 8.8ms
# Speed: 1.9ms preprocess, 8.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0413_det0.png
#
# 0: 480x640 1 ape, 8.6ms
# Speed: 1.5ms preprocess, 8.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0416_det0.png
#
# 0: 480x640 1 ape, 8.6ms
# Speed: 1.5ms preprocess, 8.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0420_det0.png
#
# 0: 480x640 1 ape, 8.7ms
# Speed: 2.0ms preprocess, 8.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0430_det0.png
#
# 0: 480x640 1 ape, 8.6ms
# Speed: 1.6ms preprocess, 8.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0450_det0.png
#
# 0: 480x640 1 ape, 8.7ms
# Speed: 1.4ms preprocess, 8.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0451_det0.png
#
# 0: 480x640 1 ape, 14.2ms
# Speed: 2.0ms preprocess, 14.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0457_det0.png
#
# 0: 480x640 1 ape, 8.6ms
# Speed: 1.3ms preprocess, 8.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0459_det0.png
#
# 0: 480x640 1 ape, 8.7ms
# Speed: 1.5ms preprocess, 8.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0466_det0.png
#
# 0: 480x640 1 ape, 8.7ms
# Speed: 1.6ms preprocess, 8.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0469_det0.png
#
# 0: 480x640 1 ape, 9.4ms
# Speed: 1.3ms preprocess, 9.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0477_det0.png
#
# 0: 480x640 1 ape, 8.7ms
# Speed: 1.8ms preprocess, 8.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0481_det0.png
#
# 0: 480x640 1 ape, 8.7ms
# Speed: 2.0ms preprocess, 8.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0483_det0.png
#
# 0: 480x640 1 ape, 14.4ms
# Speed: 1.7ms preprocess, 14.4ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0487_det0.png
#
# 0: 480x640 1 ape, 9.0ms
# Speed: 1.4ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0494_det0.png
#
# 0: 480x640 1 ape, 24.2ms
# Speed: 1.7ms preprocess, 24.2ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0509_det0.png
#
# 0: 480x640 1 ape, 8.9ms
# Speed: 1.5ms preprocess, 8.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0515_det0.png
#
# 0: 480x640 1 ape, 8.9ms
# Speed: 1.7ms preprocess, 8.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0522_det0.png
#
# 0: 480x640 1 ape, 12.9ms
# Speed: 1.3ms preprocess, 12.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0542_det0.png
#
# 0: 480x640 1 ape, 8.9ms
# Speed: 1.5ms preprocess, 8.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0550_det0.png
#
# 0: 480x640 1 ape, 14.1ms
# Speed: 1.4ms preprocess, 14.1ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0553_det0.png
#
# 0: 480x640 1 ape, 8.8ms
# Speed: 1.4ms preprocess, 8.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0556_det0.png
#
# 0: 480x640 1 ape, 23.3ms
# Speed: 2.1ms preprocess, 23.3ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0561_det0.png
#
# 0: 480x640 1 ape, 9.0ms
# Speed: 1.5ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0565_det0.png
#
# 0: 480x640 1 ape, 24.2ms
# Speed: 1.9ms preprocess, 24.2ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0569_det0.png
#
# 0: 480x640 1 ape, 17.3ms
# Speed: 1.6ms preprocess, 17.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0573_det0.png
#
# 0: 480x640 1 ape, 9.1ms
# Speed: 1.2ms preprocess, 9.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0587_det0.png
#
# 0: 480x640 1 ape, 9.0ms
# Speed: 1.7ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0590_det0.png
#
# 0: 480x640 1 ape, 9.2ms
# Speed: 1.4ms preprocess, 9.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0598_det0.png
#
# 0: 480x640 1 ape, 9.1ms
# Speed: 1.6ms preprocess, 9.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0604_det0.png
#
# 0: 480x640 1 ape, 9.2ms
# Speed: 1.8ms preprocess, 9.2ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0606_det0.png
#
# 0: 480x640 1 ape, 10.2ms
# Speed: 1.4ms preprocess, 10.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0609_det0.png
#
# 0: 480x640 1 ape, 9.3ms
# Speed: 1.5ms preprocess, 9.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0619_det0.png
#
# 0: 480x640 1 ape, 9.3ms
# Speed: 1.5ms preprocess, 9.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0621_det0.png
#
# 0: 480x640 1 ape, 9.3ms
# Speed: 1.2ms preprocess, 9.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0624_det0.png
#
# 0: 480x640 1 ape, 9.2ms
# Speed: 1.6ms preprocess, 9.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0627_det0.png
#
# 0: 480x640 1 ape, 9.2ms
# Speed: 1.7ms preprocess, 9.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0636_det0.png
#
# 0: 480x640 1 ape, 10.1ms
# Speed: 1.4ms preprocess, 10.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0647_det0.png
#
# 0: 480x640 1 ape, 9.5ms
# Speed: 1.5ms preprocess, 9.5ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0653_det0.png
#
# 0: 480x640 1 ape, 9.2ms
# Speed: 1.7ms preprocess, 9.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0658_det0.png
#
# 0: 480x640 1 ape, 9.3ms
# Speed: 1.6ms preprocess, 9.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0660_det0.png
#
# 0: 480x640 1 ape, 10.9ms
# Speed: 1.5ms preprocess, 10.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0667_det0.png
#
# 0: 480x640 1 ape, 9.3ms
# Speed: 1.6ms preprocess, 9.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0673_det0.png
#
# 0: 480x640 1 ape, 9.3ms
# Speed: 1.3ms preprocess, 9.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0674_det0.png
#
# 0: 480x640 1 ape, 9.4ms
# Speed: 1.5ms preprocess, 9.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0678_det0.png
#
# 0: 480x640 1 ape, 23.5ms
# Speed: 1.7ms preprocess, 23.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0690_det0.png
#
# 0: 480x640 1 ape, 9.4ms
# Speed: 1.8ms preprocess, 9.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0699_det0.png
#
# 0: 480x640 1 ape, 9.5ms
# Speed: 1.5ms preprocess, 9.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0704_det0.png
#
# 0: 480x640 1 ape, 9.3ms
# Speed: 1.5ms preprocess, 9.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0711_det0.png
#
# 0: 480x640 1 ape, 9.3ms
# Speed: 1.6ms preprocess, 9.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0723_det0.png
#
# 0: 480x640 1 ape, 9.4ms
# Speed: 1.4ms preprocess, 9.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0730_det0.png
#
# 0: 480x640 1 ape, 9.4ms
# Speed: 1.6ms preprocess, 9.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0734_det0.png
#
# 0: 480x640 1 ape, 9.4ms
# Speed: 1.3ms preprocess, 9.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0735_det0.png
#
# 0: 480x640 1 ape, 9.4ms
# Speed: 1.7ms preprocess, 9.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0738_det0.png
#
# 0: 480x640 1 ape, 9.4ms
# Speed: 1.3ms preprocess, 9.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0741_det0.png
#
# 0: 480x640 1 ape, 9.4ms
# Speed: 1.3ms preprocess, 9.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0749_det0.png
#
# 0: 480x640 1 ape, 9.3ms
# Speed: 1.2ms preprocess, 9.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0756_det0.png
#
# 0: 480x640 1 ape, 9.4ms
# Speed: 1.4ms preprocess, 9.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0761_det0.png
#
# 0: 480x640 1 ape, 9.4ms
# Speed: 1.8ms preprocess, 9.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0764_det0.png
#
# 0: 480x640 1 ape, 9.4ms
# Speed: 1.7ms preprocess, 9.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0776_det0.png
#
# 0: 480x640 1 ape, 9.4ms
# Speed: 1.6ms preprocess, 9.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0785_det0.png
#
# 0: 480x640 1 ape, 9.4ms
# Speed: 1.8ms preprocess, 9.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0791_det0.png
#
# 0: 480x640 1 ape, 9.4ms
# Speed: 1.7ms preprocess, 9.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0809_det0.png
#
# 0: 480x640 1 ape, 9.4ms
# Speed: 1.8ms preprocess, 9.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0819_det0.png
#
# 0: 480x640 1 ape, 9.5ms
# Speed: 1.7ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0848_det0.png
#
# 0: 480x640 1 ape, 9.4ms
# Speed: 1.7ms preprocess, 9.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0852_det0.png
#
# 0: 480x640 1 ape, 9.4ms
# Speed: 1.5ms preprocess, 9.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0873_det0.png
#
# 0: 480x640 1 ape, 9.4ms
# Speed: 1.3ms preprocess, 9.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0875_det0.png
#
# 0: 480x640 1 ape, 9.5ms
# Speed: 1.7ms preprocess, 9.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0882_det0.png
#
# 0: 480x640 1 ape, 9.4ms
# Speed: 1.5ms preprocess, 9.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0884_det0.png
#
# 0: 480x640 1 ape, 9.4ms
# Speed: 1.6ms preprocess, 9.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0888_det0.png
#
# 0: 480x640 1 ape, 9.5ms
# Speed: 1.4ms preprocess, 9.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0890_det0.png
#
# 0: 480x640 1 ape, 9.4ms
# Speed: 1.3ms preprocess, 9.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0895_det0.png
#
# 0: 480x640 1 ape, 12.1ms
# Speed: 1.6ms preprocess, 12.1ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0899_det0.png
#
# 0: 480x640 1 ape, 21.0ms
# Speed: 1.8ms preprocess, 21.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0908_det0.png
#
# 0: 480x640 1 ape, 9.5ms
# Speed: 1.6ms preprocess, 9.5ms inference, 5.8ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0914_det0.png
#
# 0: 480x640 1 ape, 9.6ms
# Speed: 1.6ms preprocess, 9.6ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0924_det0.png
#
# 0: 480x640 1 ape, 9.6ms
# Speed: 1.4ms preprocess, 9.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0927_det0.png
#
# 0: 480x640 1 ape, 9.6ms
# Speed: 1.5ms preprocess, 9.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0931_det0.png
#
# 0: 480x640 1 ape, 25.5ms
# Speed: 1.7ms preprocess, 25.5ms inference, 6.8ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0934_det0.png
#
# 0: 480x640 1 ape, 13.6ms
# Speed: 1.4ms preprocess, 13.6ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0945_det0.png
#
# 0: 480x640 1 ape, 9.6ms
# Speed: 1.5ms preprocess, 9.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0947_det0.png
#
# 0: 480x640 1 ape, 9.7ms
# Speed: 1.4ms preprocess, 9.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0956_det0.png
#
# 0: 480x640 1 ape, 9.7ms
# Speed: 1.8ms preprocess, 9.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0960_det0.png
#
# 0: 480x640 1 ape, 9.7ms
# Speed: 1.8ms preprocess, 9.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0962_det0.png
#
# 0: 480x640 1 ape, 9.6ms
# Speed: 1.6ms preprocess, 9.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0965_det0.png
#
# 0: 480x640 1 ape, 9.8ms
# Speed: 1.4ms preprocess, 9.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0967_det0.png
#
# 0: 480x640 1 ape, 9.8ms
# Speed: 1.4ms preprocess, 9.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0975_det0.png
#
# 0: 480x640 1 ape, 9.7ms
# Speed: 1.5ms preprocess, 9.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0976_det0.png
#
# 0: 480x640 1 ape, 9.6ms
# Speed: 1.3ms preprocess, 9.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0978_det0.png
#
# 0: 480x640 1 ape, 9.8ms
# Speed: 1.6ms preprocess, 9.8ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img0986_det0.png
#
# 0: 480x640 1 ape, 10.3ms
# Speed: 2.1ms preprocess, 10.3ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img1002_det0.png
#
# 0: 480x640 1 ape, 9.7ms
# Speed: 1.3ms preprocess, 9.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img1019_det0.png
#
# 0: 480x640 1 ape, 9.7ms
# Speed: 1.5ms preprocess, 9.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img1029_det0.png
#
# 0: 480x640 1 ape, 9.8ms
# Speed: 1.6ms preprocess, 9.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img1033_det0.png
#
# 0: 480x640 1 ape, 16.3ms
# Speed: 1.4ms preprocess, 16.3ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img1038_det0.png
#
# 0: 480x640 1 ape, 12.7ms
# Speed: 1.7ms preprocess, 12.7ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img1051_det0.png
#
# 0: 480x640 1 ape, 9.8ms
# Speed: 1.4ms preprocess, 9.8ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img1076_det0.png
#
# 0: 480x640 1 ape, 9.9ms
# Speed: 1.3ms preprocess, 9.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img1079_det0.png
#
# 0: 480x640 1 ape, 9.9ms
# Speed: 1.4ms preprocess, 9.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img1081_det0.png
#
# 0: 480x640 1 ape, 10.1ms
# Speed: 1.4ms preprocess, 10.1ms inference, 6.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img1084_det0.png
#
# 0: 480x640 1 ape, 9.9ms
# Speed: 1.3ms preprocess, 9.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img1095_det0.png
#
# 0: 480x640 1 ape, 9.9ms
# Speed: 1.4ms preprocess, 9.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img1108_det0.png
#
# 0: 480x640 1 ape, 9.9ms
# Speed: 1.3ms preprocess, 9.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img1117_det0.png
#
# 0: 480x640 1 ape, 9.9ms
# Speed: 1.4ms preprocess, 9.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img1122_det0.png
#
# 0: 480x640 1 ape, 9.8ms
# Speed: 1.9ms preprocess, 9.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img1125_det0.png
#
# 0: 480x640 1 ape, 9.9ms
# Speed: 1.7ms preprocess, 9.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img1130_det0.png
#
# 0: 480x640 1 ape, 9.9ms
# Speed: 1.3ms preprocess, 9.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img1139_det0.png
#
# 0: 480x640 1 ape, 10.1ms
# Speed: 1.3ms preprocess, 10.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img1145_det0.png
#
# 0: 480x640 1 ape, 9.9ms
# Speed: 1.3ms preprocess, 9.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img1148_det0.png
#
# 0: 480x640 1 ape, 9.9ms
# Speed: 1.2ms preprocess, 9.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img1154_det0.png
#
# 0: 480x640 1 ape, 10.0ms
# Speed: 1.5ms preprocess, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img1161_det0.png
#
# 0: 480x640 1 ape, 25.0ms
# Speed: 2.1ms preprocess, 25.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img1175_det0.png
#
# 0: 480x640 1 ape, 15.0ms
# Speed: 1.4ms preprocess, 15.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img1179_det0.png
#
# 0: 480x640 1 ape, 10.1ms
# Speed: 1.3ms preprocess, 10.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img1196_det0.png
#
# 0: 480x640 1 ape, 22.8ms
# Speed: 1.4ms preprocess, 22.8ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img1197_det0.png
#
# 0: 480x640 1 ape, 10.1ms
# Speed: 1.6ms preprocess, 10.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img1207_det0.png
#
# 0: 480x640 1 ape, 10.3ms
# Speed: 1.2ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img1210_det0.png
#
# 0: 480x640 1 ape, 10.1ms
# Speed: 1.2ms preprocess, 10.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img1212_det0.png
#
# 0: 480x640 1 ape, 14.5ms
# Speed: 1.7ms preprocess, 14.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img1226_det0.png
#
# 0: 480x640 1 ape, 10.1ms
# Speed: 1.5ms preprocess, 10.1ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img1228_det0.png
#
# 0: 480x640 1 ape, 10.1ms
# Speed: 1.4ms preprocess, 10.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls01_img1235_det0.png
# [02] Processing 181 training images.
#
# 0: 480x640 1 benchvise, 10.3ms
# Speed: 1.5ms preprocess, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0024_det0.png
#
# 0: 480x640 1 benchvise, 10.1ms
# Speed: 2.1ms preprocess, 10.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0030_det0.png
#
# 0: 480x640 1 benchvise, 19.7ms
# Speed: 1.3ms preprocess, 19.7ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0045_det0.png
#
# 0: 480x640 1 benchvise, 10.2ms
# Speed: 1.4ms preprocess, 10.2ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0053_det0.png
#
# 0: 480x640 1 benchvise, 10.2ms
# Speed: 1.4ms preprocess, 10.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0063_det0.png
#
# 0: 480x640 1 benchvise, 10.5ms
# Speed: 1.4ms preprocess, 10.5ms inference, 6.8ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0065_det0.png
#
# 0: 480x640 1 benchvise, 19.5ms
# Speed: 1.6ms preprocess, 19.5ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0071_det0.png
#
# 0: 480x640 1 benchvise, 12.1ms
# Speed: 1.4ms preprocess, 12.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0072_det0.png
#
# 0: 480x640 1 benchvise, 10.4ms
# Speed: 1.3ms preprocess, 10.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0076_det0.png
#
# 0: 480x640 1 benchvise, 10.3ms
# Speed: 1.5ms preprocess, 10.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0078_det0.png
#
# 0: 480x640 1 benchvise, 10.3ms
# Speed: 1.4ms preprocess, 10.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0091_det0.png
#
# 0: 480x640 1 benchvise, 10.3ms
# Speed: 1.6ms preprocess, 10.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0092_det0.png
#
# 0: 480x640 1 benchvise, 10.3ms
# Speed: 1.7ms preprocess, 10.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0095_det0.png
#
# 0: 480x640 1 benchvise, 10.5ms
# Speed: 1.9ms preprocess, 10.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0099_det0.png
#
# 0: 480x640 1 benchvise, 10.4ms
# Speed: 1.6ms preprocess, 10.4ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0103_det0.png
#
# 0: 480x640 1 benchvise, 23.9ms
# Speed: 1.8ms preprocess, 23.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0106_det0.png
#
# 0: 480x640 1 benchvise, 10.4ms
# Speed: 1.5ms preprocess, 10.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0116_det0.png
#
# 0: 480x640 1 benchvise, 23.8ms
# Speed: 1.4ms preprocess, 23.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0123_det0.png
#
# 0: 480x640 1 benchvise, 10.4ms
# Speed: 1.7ms preprocess, 10.4ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0130_det0.png
#
# 0: 480x640 1 benchvise, 10.6ms
# Speed: 1.5ms preprocess, 10.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0134_det0.png
#
# 0: 480x640 1 benchvise, 10.5ms
# Speed: 1.7ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0139_det0.png
#
# 0: 480x640 1 benchvise, 10.4ms
# Speed: 1.6ms preprocess, 10.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0146_det0.png
#
# 0: 480x640 1 benchvise, 10.5ms
# Speed: 1.7ms preprocess, 10.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0152_det0.png
#
# 0: 480x640 1 benchvise, 19.7ms
# Speed: 1.6ms preprocess, 19.7ms inference, 5.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0153_det0.png
#
# 0: 480x640 1 benchvise, 10.5ms
# Speed: 1.2ms preprocess, 10.5ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0155_det0.png
#
# 0: 480x640 1 benchvise, 10.4ms
# Speed: 1.5ms preprocess, 10.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0157_det0.png
#
# 0: 480x640 1 benchvise, 10.5ms
# Speed: 1.3ms preprocess, 10.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0158_det0.png
#
# 0: 480x640 1 benchvise, 10.6ms
# Speed: 1.5ms preprocess, 10.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0161_det0.png
#
# 0: 480x640 1 benchvise, 10.6ms
# Speed: 1.7ms preprocess, 10.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0163_det0.png
#
# 0: 480x640 1 benchvise, 10.5ms
# Speed: 1.5ms preprocess, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0167_det0.png
#
# 0: 480x640 1 benchvise, 10.6ms
# Speed: 1.8ms preprocess, 10.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0172_det0.png
#
# 0: 480x640 1 benchvise, 12.1ms
# Speed: 1.6ms preprocess, 12.1ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0174_det0.png
#
# 0: 480x640 1 benchvise, 10.6ms
# Speed: 1.5ms preprocess, 10.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0183_det0.png
#
# 0: 480x640 1 benchvise, 14.9ms
# Speed: 1.6ms preprocess, 14.9ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0200_det0.png
#
# 0: 480x640 1 benchvise, 10.6ms
# Speed: 1.4ms preprocess, 10.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0214_det0.png
#
# 0: 480x640 1 benchvise, 10.8ms
# Speed: 1.3ms preprocess, 10.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0221_det0.png
#
# 0: 480x640 1 benchvise, 10.7ms
# Speed: 1.4ms preprocess, 10.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0226_det0.png
#
# 0: 480x640 1 benchvise, 10.8ms
# Speed: 1.3ms preprocess, 10.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0235_det0.png
#
# 0: 480x640 1 benchvise, 15.4ms
# Speed: 1.6ms preprocess, 15.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0239_det0.png
#
# 0: 480x640 1 benchvise, 13.8ms
# Speed: 1.6ms preprocess, 13.8ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0243_det0.png
#
# 0: 480x640 1 benchvise, 11.7ms
# Speed: 1.8ms preprocess, 11.7ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0271_det0.png
#
# 0: 480x640 1 benchvise, 24.3ms
# Speed: 1.6ms preprocess, 24.3ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0274_det0.png
#
# 0: 480x640 1 benchvise, 10.8ms
# Speed: 1.4ms preprocess, 10.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0277_det0.png
#
# 0: 480x640 1 benchvise, 14.4ms
# Speed: 1.7ms preprocess, 14.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0286_det0.png
#
# 0: 480x640 1 benchvise, 13.7ms
# Speed: 1.5ms preprocess, 13.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0291_det0.png
#
# 0: 480x640 1 benchvise, 10.7ms
# Speed: 1.4ms preprocess, 10.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0294_det0.png
#
# 0: 480x640 1 benchvise, 10.8ms
# Speed: 1.2ms preprocess, 10.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0302_det0.png
#
# 0: 480x640 1 benchvise, 10.9ms
# Speed: 1.3ms preprocess, 10.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0307_det0.png
#
# 0: 480x640 1 benchvise, 13.8ms
# Speed: 5.3ms preprocess, 13.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0314_det0.png
#
# 0: 480x640 1 benchvise, 11.0ms
# Speed: 1.3ms preprocess, 11.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0320_det0.png
#
# 0: 480x640 1 benchvise, 11.0ms
# Speed: 1.6ms preprocess, 11.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0324_det0.png
#
# 0: 480x640 1 benchvise, 10.9ms
# Speed: 1.5ms preprocess, 10.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0347_det0.png
#
# 0: 480x640 1 benchvise, 10.9ms
# Speed: 1.2ms preprocess, 10.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0350_det0.png
#
# 0: 480x640 1 benchvise, 10.9ms
# Speed: 1.4ms preprocess, 10.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0355_det0.png
#
# 0: 480x640 1 benchvise, 11.0ms
# Speed: 1.3ms preprocess, 11.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0364_det0.png
#
# 0: 480x640 1 benchvise, 11.1ms
# Speed: 1.6ms preprocess, 11.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0367_det0.png
#
# 0: 480x640 1 benchvise, 10.9ms
# Speed: 1.6ms preprocess, 10.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0369_det0.png
#
# 0: 480x640 1 benchvise, 11.0ms
# Speed: 1.5ms preprocess, 11.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0376_det0.png
#
# 0: 480x640 1 benchvise, 11.0ms
# Speed: 1.3ms preprocess, 11.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0377_det0.png
#
# 0: 480x640 1 benchvise, 11.1ms
# Speed: 2.0ms preprocess, 11.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0379_det0.png
#
# 0: 480x640 1 benchvise, 11.1ms
# Speed: 1.8ms preprocess, 11.1ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0383_det0.png
#
# 0: 480x640 1 benchvise, 11.0ms
# Speed: 1.3ms preprocess, 11.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0384_det0.png
#
# 0: 480x640 1 benchvise, 10.9ms
# Speed: 1.5ms preprocess, 10.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0387_det0.png
#
# 0: 480x640 1 benchvise, 11.0ms
# Speed: 1.4ms preprocess, 11.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0394_det0.png
#
# 0: 480x640 1 benchvise, 11.0ms
# Speed: 1.5ms preprocess, 11.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0402_det0.png
#
# 0: 480x640 1 benchvise, 17.3ms
# Speed: 1.3ms preprocess, 17.3ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0406_det0.png
#
# 0: 480x640 1 benchvise, 11.7ms
# Speed: 1.7ms preprocess, 11.7ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0410_det0.png
#
# 0: 480x640 1 benchvise, 11.0ms
# Speed: 1.2ms preprocess, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0413_det0.png
#
# 0: 480x640 1 benchvise, 11.1ms
# Speed: 1.7ms preprocess, 11.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0422_det0.png
#
# 0: 480x640 1 benchvise, 25.3ms
# Speed: 1.7ms preprocess, 25.3ms inference, 6.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0425_det0.png
#
# 0: 480x640 1 benchvise, 11.6ms
# Speed: 1.5ms preprocess, 11.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0430_det0.png
#
# 0: 480x640 1 benchvise, 11.1ms
# Speed: 1.2ms preprocess, 11.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0434_det0.png
#
# 0: 480x640 1 benchvise, 11.0ms
# Speed: 1.7ms preprocess, 11.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0441_det0.png
#
# 0: 480x640 1 benchvise, 23.4ms
# Speed: 1.7ms preprocess, 23.4ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0446_det0.png
#
# 0: 480x640 1 benchvise, 18.3ms
# Speed: 1.5ms preprocess, 18.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0451_det0.png
#
# 0: 480x640 1 benchvise, 11.3ms
# Speed: 2.0ms preprocess, 11.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0456_det0.png
#
# 0: 480x640 1 benchvise, 11.1ms
# Speed: 1.3ms preprocess, 11.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0461_det0.png
#
# 0: 480x640 1 benchvise, 11.1ms
# Speed: 1.2ms preprocess, 11.1ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0465_det0.png
#
# 0: 480x640 1 benchvise, 11.2ms
# Speed: 1.3ms preprocess, 11.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0471_det0.png
#
# 0: 480x640 1 benchvise, 11.3ms
# Speed: 1.3ms preprocess, 11.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0480_det0.png
#
# 0: 480x640 1 benchvise, 11.3ms
# Speed: 1.5ms preprocess, 11.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0483_det0.png
#
# 0: 480x640 1 benchvise, 11.3ms
# Speed: 1.5ms preprocess, 11.3ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0493_det0.png
#
# 0: 480x640 1 benchvise, 11.2ms
# Speed: 1.4ms preprocess, 11.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0496_det0.png
#
# 0: 480x640 1 benchvise, 11.3ms
# Speed: 1.5ms preprocess, 11.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0498_det0.png
#
# 0: 480x640 1 benchvise, 11.4ms
# Speed: 1.4ms preprocess, 11.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0507_det0.png
#
# 0: 480x640 1 benchvise, 11.4ms
# Speed: 1.5ms preprocess, 11.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0512_det0.png
#
# 0: 480x640 1 benchvise, 10.6ms
# Speed: 1.6ms preprocess, 10.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0525_det0.png
#
# 0: 480x640 1 benchvise, 10.6ms
# Speed: 1.5ms preprocess, 10.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0527_det0.png
#
# 0: 480x640 1 benchvise, 10.7ms
# Speed: 1.5ms preprocess, 10.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0532_det0.png
#
# 0: 480x640 1 benchvise, 10.7ms
# Speed: 1.4ms preprocess, 10.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0533_det0.png
#
# 0: 480x640 1 benchvise, 10.7ms
# Speed: 1.2ms preprocess, 10.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0534_det0.png
#
# 0: 480x640 1 benchvise, 10.8ms
# Speed: 1.4ms preprocess, 10.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0539_det0.png
#
# 0: 480x640 1 benchvise, 10.6ms
# Speed: 1.4ms preprocess, 10.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0554_det0.png
#
# 0: 480x640 1 benchvise, 10.7ms
# Speed: 1.9ms preprocess, 10.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0556_det0.png
#
# 0: 480x640 1 benchvise, 10.7ms
# Speed: 1.5ms preprocess, 10.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0568_det0.png
#
# 0: 480x640 1 benchvise, 15.6ms
# Speed: 1.5ms preprocess, 15.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0571_det0.png
#
# 0: 480x640 1 benchvise, 12.9ms
# Speed: 1.6ms preprocess, 12.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0573_det0.png
#
# 0: 480x640 1 benchvise, 11.5ms
# Speed: 1.2ms preprocess, 11.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0576_det0.png
#
# 0: 480x640 1 benchvise, 10.8ms
# Speed: 1.7ms preprocess, 10.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0598_det0.png
#
# 0: 480x640 1 benchvise, 23.5ms
# Speed: 1.7ms preprocess, 23.5ms inference, 6.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0603_det0.png
#
# 0: 480x640 1 benchvise, 10.7ms
# Speed: 1.2ms preprocess, 10.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0604_det0.png
#
# 0: 480x640 1 benchvise, 10.7ms
# Speed: 1.5ms preprocess, 10.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0609_det0.png
#
# 0: 480x640 1 benchvise, 10.8ms
# Speed: 1.6ms preprocess, 10.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0627_det0.png
#
# 0: 480x640 1 benchvise, 23.7ms
# Speed: 1.7ms preprocess, 23.7ms inference, 6.6ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0635_det0.png
#
# 0: 480x640 1 benchvise, 10.7ms
# Speed: 1.8ms preprocess, 10.7ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0641_det0.png
#
# 0: 480x640 1 benchvise, 24.7ms
# Speed: 1.9ms preprocess, 24.7ms inference, 6.6ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0649_det0.png
#
# 0: 480x640 1 benchvise, 19.0ms
# Speed: 1.6ms preprocess, 19.0ms inference, 5.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0653_det0.png
#
# 0: 480x640 1 benchvise, 10.7ms
# Speed: 1.5ms preprocess, 10.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0656_det0.png
#
# 0: 480x640 1 benchvise, 10.7ms
# Speed: 1.5ms preprocess, 10.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0659_det0.png
#
# 0: 480x640 1 benchvise, 10.6ms
# Speed: 1.2ms preprocess, 10.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0668_det0.png
#
# 0: 480x640 1 benchvise, 10.8ms
# Speed: 1.3ms preprocess, 10.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0676_det0.png
#
# 0: 480x640 1 benchvise, 10.7ms
# Speed: 1.2ms preprocess, 10.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0692_det0.png
#
# 0: 480x640 1 benchvise, 10.7ms
# Speed: 1.4ms preprocess, 10.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0697_det0.png
#
# 0: 480x640 1 benchvise, 10.8ms
# Speed: 1.4ms preprocess, 10.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0706_det0.png
#
# 0: 480x640 1 benchvise, 10.8ms
# Speed: 1.5ms preprocess, 10.8ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0715_det0.png
#
# 0: 480x640 1 benchvise, 10.7ms
# Speed: 1.6ms preprocess, 10.7ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0717_det0.png
#
# 0: 480x640 1 benchvise, 10.7ms
# Speed: 1.4ms preprocess, 10.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0726_det0.png
#
# 0: 480x640 1 benchvise, 10.8ms
# Speed: 1.4ms preprocess, 10.8ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0735_det0.png
#
# 0: 480x640 1 benchvise, 10.7ms
# Speed: 1.4ms preprocess, 10.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0744_det0.png
#
# 0: 480x640 1 benchvise, 10.7ms
# Speed: 1.4ms preprocess, 10.7ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls02_img0747_det0.png
#
# ...
# ✅ Saved: cls13_img0481_det0.png
#
# 0: 480x640 1 iron, 23.6ms
# Speed: 1.6ms preprocess, 23.6ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0488_det0.png
#
# 0: 480x640 1 iron, 12.0ms
# Speed: 1.5ms preprocess, 12.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0492_det0.png
#
# 0: 480x640 1 iron, 24.0ms
# Speed: 1.6ms preprocess, 24.0ms inference, 5.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0500_det0.png
#
# 0: 480x640 1 iron, 12.0ms
# Speed: 1.4ms preprocess, 12.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0501_det0.png
#
# 0: 480x640 1 iron, 23.2ms
# Speed: 1.7ms preprocess, 23.2ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0506_det0.png
#
# 0: 480x640 1 iron, 23.2ms
# Speed: 1.6ms preprocess, 23.2ms inference, 6.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0514_det0.png
#
# 0: 480x640 1 iron, 23.7ms
# Speed: 1.7ms preprocess, 23.7ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0518_det0.png
#
# 0: 480x640 1 iron, 12.0ms
# Speed: 1.6ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0520_det0.png
#
# 0: 480x640 1 iron, 23.8ms
# Speed: 1.4ms preprocess, 23.8ms inference, 5.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0524_det0.png
#
# 0: 480x640 1 iron, 19.4ms
# Speed: 1.7ms preprocess, 19.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0527_det0.png
#
# 0: 480x640 1 iron, 12.0ms
# Speed: 1.5ms preprocess, 12.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0528_det0.png
#
# 0: 480x640 1 iron, 12.1ms
# Speed: 1.6ms preprocess, 12.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0530_det0.png
#
# 0: 480x640 1 iron, 12.0ms
# Speed: 1.3ms preprocess, 12.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0540_det0.png
#
# 0: 480x640 1 iron, 12.0ms
# Speed: 1.4ms preprocess, 12.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0549_det0.png
#
# 0: 480x640 1 iron, 12.1ms
# Speed: 1.5ms preprocess, 12.1ms inference, 7.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0555_det0.png
#
# 0: 480x640 1 iron, 11.9ms
# Speed: 1.4ms preprocess, 11.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0559_det0.png
#
# 0: 480x640 1 iron, 22.3ms
# Speed: 1.6ms preprocess, 22.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0566_det0.png
#
# 0: 480x640 1 iron, 12.0ms
# Speed: 1.6ms preprocess, 12.0ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0577_det0.png
#
# 0: 480x640 1 iron, 22.9ms
# Speed: 1.5ms preprocess, 22.9ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0578_det0.png
#
# 0: 480x640 1 iron, 23.5ms
# Speed: 2.1ms preprocess, 23.5ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0580_det0.png
#
# 0: 480x640 1 iron, 23.0ms
# Speed: 1.7ms preprocess, 23.0ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0583_det0.png
#
# 0: 480x640 1 iron, 12.2ms
# Speed: 1.3ms preprocess, 12.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0590_det0.png
#
# 0: 480x640 1 iron, 12.0ms
# Speed: 1.4ms preprocess, 12.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0596_det0.png
#
# 0: 480x640 1 iron, 12.9ms
# Speed: 1.4ms preprocess, 12.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0598_det0.png
#
# 0: 480x640 1 iron, 23.4ms
# Speed: 1.7ms preprocess, 23.4ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0607_det0.png
#
# 0: 480x640 1 iron, 23.2ms
# Speed: 2.1ms preprocess, 23.2ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0614_det0.png
#
# 0: 480x640 1 iron, 23.2ms
# Speed: 1.5ms preprocess, 23.2ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0637_det0.png
#
# 0: 480x640 1 iron, 23.3ms
# Speed: 1.4ms preprocess, 23.3ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0648_det0.png
#
# 0: 480x640 1 iron, 13.0ms
# Speed: 1.3ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0659_det0.png
#
# 0: 480x640 1 iron, 22.6ms
# Speed: 1.4ms preprocess, 22.6ms inference, 5.8ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0662_det0.png
#
# 0: 480x640 1 iron, 20.2ms
# Speed: 1.8ms preprocess, 20.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0667_det0.png
#
# 0: 480x640 1 iron, 21.5ms
# Speed: 1.6ms preprocess, 21.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0671_det0.png
#
# 0: 480x640 1 iron, 23.2ms
# Speed: 1.8ms preprocess, 23.2ms inference, 6.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0687_det0.png
#
# 0: 480x640 1 iron, 16.2ms
# Speed: 1.6ms preprocess, 16.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0694_det0.png
#
# 0: 480x640 1 iron, 13.2ms
# Speed: 1.5ms preprocess, 13.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0707_det0.png
#
# 0: 480x640 1 iron, 13.2ms
# Speed: 1.2ms preprocess, 13.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0711_det0.png
#
# 0: 480x640 1 iron, 13.1ms
# Speed: 1.3ms preprocess, 13.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0713_det0.png
#
# 0: 480x640 1 iron, 13.2ms
# Speed: 1.3ms preprocess, 13.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0717_det0.png
#
# 0: 480x640 1 iron, 13.3ms
# Speed: 1.5ms preprocess, 13.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0722_det0.png
#
# 0: 480x640 1 iron, 13.2ms
# Speed: 1.6ms preprocess, 13.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0732_det0.png
#
# 0: 480x640 1 iron, 13.1ms
# Speed: 1.3ms preprocess, 13.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0737_det0.png
#
# 0: 480x640 1 iron, 13.2ms
# Speed: 1.5ms preprocess, 13.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0739_det0.png
#
# 0: 480x640 1 iron, 13.2ms
# Speed: 1.5ms preprocess, 13.2ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0749_det0.png
#
# 0: 480x640 1 iron, 13.2ms
# Speed: 1.9ms preprocess, 13.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0755_det0.png
#
# 0: 480x640 1 iron, 13.3ms
# Speed: 1.6ms preprocess, 13.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0760_det0.png
#
# 0: 480x640 1 iron, 13.0ms
# Speed: 1.6ms preprocess, 13.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0771_det0.png
#
# 0: 480x640 1 iron, 12.7ms
# Speed: 1.6ms preprocess, 12.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0772_det0.png
#
# 0: 480x640 1 iron, 12.8ms
# Speed: 1.6ms preprocess, 12.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0780_det0.png
#
# 0: 480x640 1 iron, 12.7ms
# Speed: 1.7ms preprocess, 12.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0789_det0.png
#
# 0: 480x640 1 iron, 12.8ms
# Speed: 1.4ms preprocess, 12.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0792_det0.png
#
# 0: 480x640 1 iron, 12.8ms
# Speed: 1.5ms preprocess, 12.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0794_det0.png
#
# 0: 480x640 1 iron, 12.8ms
# Speed: 1.7ms preprocess, 12.8ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0803_det0.png
#
# 0: 480x640 1 iron, 11.9ms
# Speed: 1.3ms preprocess, 11.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0805_det0.png
#
# 0: 480x640 1 iron, 11.8ms
# Speed: 1.1ms preprocess, 11.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0808_det0.png
#
# 0: 480x640 1 iron, 12.1ms
# Speed: 1.5ms preprocess, 12.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0831_det0.png
#
# 0: 480x640 1 iron, 11.9ms
# Speed: 1.3ms preprocess, 11.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0841_det0.png
#
# 0: 480x640 1 iron, 11.8ms
# Speed: 1.3ms preprocess, 11.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0842_det0.png
#
# 0: 480x640 1 iron, 11.9ms
# Speed: 1.4ms preprocess, 11.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0846_det0.png
#
# 0: 480x640 1 iron, 11.8ms
# Speed: 1.6ms preprocess, 11.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0847_det0.png
#
# 0: 480x640 1 iron, 11.9ms
# Speed: 1.5ms preprocess, 11.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0848_det0.png
#
# 0: 480x640 1 iron, 12.0ms
# Speed: 1.8ms preprocess, 12.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0853_det0.png
#
# 0: 480x640 1 iron, 11.8ms
# Speed: 1.6ms preprocess, 11.8ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0874_det0.png
#
# 0: 480x640 1 iron, 11.9ms
# Speed: 1.5ms preprocess, 11.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0888_det0.png
#
# 0: 480x640 1 iron, 11.8ms
# Speed: 1.2ms preprocess, 11.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0904_det0.png
#
# 0: 480x640 1 iron, 11.8ms
# Speed: 1.4ms preprocess, 11.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0909_det0.png
#
# 0: 480x640 1 iron, 21.9ms
# Speed: 1.6ms preprocess, 21.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0915_det0.png
#
# 0: 480x640 1 iron, 23.2ms
# Speed: 1.7ms preprocess, 23.2ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0916_det0.png
#
# 0: 480x640 1 iron, 11.5ms
# Speed: 1.4ms preprocess, 11.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0920_det0.png
#
# 0: 480x640 1 iron, 11.5ms
# Speed: 1.7ms preprocess, 11.5ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0933_det0.png
#
# 0: 480x640 1 iron, 24.5ms
# Speed: 1.6ms preprocess, 24.5ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0938_det0.png
#
# 0: 480x640 1 iron, 24.4ms
# Speed: 1.6ms preprocess, 24.4ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0942_det0.png
#
# 0: 480x640 1 iron, 25.4ms
# Speed: 3.0ms preprocess, 25.4ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0947_det0.png
#
# 0: 480x640 1 iron, 11.4ms
# Speed: 1.3ms preprocess, 11.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0950_det0.png
#
# 0: 480x640 1 iron, 18.6ms
# Speed: 1.7ms preprocess, 18.6ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0954_det0.png
#
# 0: 480x640 1 iron, 11.5ms
# Speed: 1.4ms preprocess, 11.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0961_det0.png
#
# 0: 480x640 1 iron, 11.4ms
# Speed: 1.5ms preprocess, 11.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0969_det0.png
#
# 0: 480x640 1 iron, 13.3ms
# Speed: 1.7ms preprocess, 13.3ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0974_det0.png
#
# 0: 480x640 1 iron, 11.5ms
# Speed: 1.2ms preprocess, 11.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0997_det0.png
#
# 0: 480x640 1 iron, 11.5ms
# Speed: 1.6ms preprocess, 11.5ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img0999_det0.png
#
# 0: 480x640 1 iron, 11.4ms
# Speed: 1.2ms preprocess, 11.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img1002_det0.png
#
# 0: 480x640 1 iron, 11.5ms
# Speed: 1.6ms preprocess, 11.5ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img1017_det0.png
#
# 0: 480x640 1 iron, 11.4ms
# Speed: 1.5ms preprocess, 11.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img1022_det0.png
#
# 0: 480x640 1 iron, 11.4ms
# Speed: 1.5ms preprocess, 11.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img1023_det0.png
#
# 0: 480x640 1 iron, 11.4ms
# Speed: 1.6ms preprocess, 11.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img1024_det0.png
#
# 0: 480x640 1 iron, 11.4ms
# Speed: 1.6ms preprocess, 11.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img1038_det0.png
#
# 0: 480x640 1 iron, 11.5ms
# Speed: 1.2ms preprocess, 11.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img1062_det0.png
#
# 0: 480x640 1 iron, 22.8ms
# Speed: 1.7ms preprocess, 22.8ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img1069_det0.png
#
# 0: 480x640 1 iron, 11.4ms
# Speed: 1.4ms preprocess, 11.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img1072_det0.png
#
# 0: 480x640 1 iron, 11.5ms
# Speed: 1.4ms preprocess, 11.5ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img1073_det0.png
#
# 0: 480x640 1 iron, 23.6ms
# Speed: 1.6ms preprocess, 23.6ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img1077_det0.png
#
# 0: 480x640 1 iron, 11.5ms
# Speed: 1.2ms preprocess, 11.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img1087_det0.png
#
# 0: 480x640 1 iron, 18.1ms
# Speed: 2.1ms preprocess, 18.1ms inference, 6.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img1088_det0.png
#
# 0: 480x640 1 iron, 11.4ms
# Speed: 1.4ms preprocess, 11.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img1094_det0.png
#
# 0: 480x640 1 iron, 16.5ms
# Speed: 1.5ms preprocess, 16.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img1100_det0.png
#
# 0: 480x640 1 iron, 24.8ms
# Speed: 1.7ms preprocess, 24.8ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img1103_det0.png
#
# 0: 480x640 1 iron, 17.6ms
# Speed: 1.6ms preprocess, 17.6ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img1121_det0.png
#
# 0: 480x640 1 iron, 11.4ms
# Speed: 1.4ms preprocess, 11.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img1127_det0.png
#
# 0: 480x640 1 iron, 11.6ms
# Speed: 1.4ms preprocess, 11.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img1130_det0.png
#
# 0: 480x640 1 iron, 11.5ms
# Speed: 1.5ms preprocess, 11.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img1132_det0.png
#
# 0: 480x640 1 iron, 18.7ms
# Speed: 1.5ms preprocess, 18.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img1133_det0.png
#
# 0: 480x640 1 iron, 11.4ms
# Speed: 1.3ms preprocess, 11.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img1145_det0.png
#
# 0: 480x640 1 iron, 16.1ms
# Speed: 1.7ms preprocess, 16.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# ✅ Saved: cls13_img1148_det0.png
# ✅ All YOLOv8 crops saved for all classes.

# %%
import os
import yaml
import csv

# ========== CONFIGURATION ==========
CROP_FOLDER = 'Phase3_RGB_Crops'
LINEMOD_ROOT = 'dataset/Linemod_preprocessed/data'
OUTPUT_CSV = 'pose_labels.csv'
# ===================================

# 🔹 Helper to read YAML
def load_yaml(path):
    with open(path, 'r') as f:
        return yaml.safe_load(f)

# 🔸 Open CSV file for writing
with open(OUTPUT_CSV, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    # Write header
    writer.writerow(['crop_path', 'class_id', 'image_id', 'x', 'y', 'z'] +
                    [f'R{i}' for i in range(1, 10)])  # R1 to R9 for 3×3 matrix

    for filename in os.listdir(CROP_FOLDER):
        if not filename.endswith('.png'):
            continue

        # Example filename: cls01_img000123_det0.png
        parts = filename.split('_')
        class_id = parts[0][3:]     # '01'
        image_id = parts[1][3:]     # '000123'

        gt_path = os.path.join(LINEMOD_ROOT, class_id, 'gt.yml')
        if not os.path.exists(gt_path):
            print(f"[SKIP] Missing gt.yml for class {class_id}")
            continue

        gt_data = load_yaml(gt_path)

        img_index = int(image_id)
        if img_index not in gt_data:
            print(f"[SKIP] No pose for image {image_id} in {class_id}")
            continue

        # Use the FIRST object instance in that image
        obj = gt_data[img_index][0]
        R = obj['cam_R_m2c']  # list of 9 floats
        t = obj['cam_t_m2c']  # list of 3 floats (usually in mm)

        # Convert to meters (optional)
        t = [val / 1000.0 for val in t]

        # Write a row
        writer.writerow([os.path.join(CROP_FOLDER, filename), class_id, image_id] + t + R)

print("✅ Pose label file saved as:", OUTPUT_CSV)
# Out:
# ✅ Pose label file saved as: pose_labels.csv

# %%
import torch
from torch.utils.data import Dataset
from torchvision import transforms
import pandas as pd
from PIL import Image

class PoseDataset(Dataset):
    def __init__(self, csv_path, image_size=224):
        self.data = pd.read_csv(csv_path)

        self.transform = transforms.Compose([
            transforms.Resize((image_size, image_size)),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406],  # ImageNet mean
                                 std=[0.229, 0.224, 0.225])   # ImageNet std
        ])

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        row = self.data.iloc[idx]

        # Load and transform image
        image = Image.open(row['crop_path']).convert('RGB')
        image = self.transform(image)

        # Load pose (3 translation + 9 rotation values)
        pose = row[['x', 'y', 'z'] + [f'R{i}' for i in range(1, 10)]].values.astype('float32')
        pose = torch.tensor(pose)

        return image, pose

# %%
dataset = PoseDataset('pose_labels.csv')
image, pose = dataset[0]

print("Image shape:", image.shape)  # [3, 224, 224]
print("Pose vector:", pose)         # Tensor of shape [12]
# Out:
# Image shape: torch.Size([3, 224, 224])
# Pose vector: tensor([ 0.1177, -0.0283,  0.9279, -0.9932, -0.1094,  0.0408, -0.1023,  0.6473, -0.7554,  0.0562, -0.7544, -0.6540])

# %%
import torch
import torch.nn as nn
import torchvision.models as models

class PoseRegressionNet(nn.Module):
    def __init__(self, pretrained=True):
        super(PoseRegressionNet, self).__init__()

        # 🔹 Load pretrained ResNet18 and remove its classifier
        resnet = models.resnet18(pretrained=pretrained)
        self.backbone = nn.Sequential(*list(resnet.children())[:-1])  # Remove final FC layer

        # 🔹 Add a new regression head: input 512-d → output 12-d
        self.regressor = nn.Sequential(
            nn.Flatten(),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128, 12)  # Output: x, y, z, r11..r33
        )

    def forward(self, x):
        features = self.backbone(x)     # Shape: [B, 512, 1, 1]
        output = self.regressor(features)  # Shape: [B, 12]
        return output

# %%
model = PoseRegressionNet()
print(model)
# Out:
# /home/erythm/anaconda3/envs/6d/lib/python3.13/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/erythm/anaconda3/envs/6d/lib/python3.13/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /home/erythm/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 44.7M/44.7M [00:22<00:00, 2.08MB/s]
# PoseRegressionNet(
#   (backbone): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (8): AdaptiveAvgPool2d(output_size=(1, 1))
#   )
#   (regressor): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=512, out_features=256, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=256, out_features=128, bias=True)
#     (4): ReLU()
#     (5): Linear(in_features=128, out_features=12, bias=True)
#   )
# )

# %%
import torch
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.optim as optim


# Load dataset
dataset = PoseDataset('pose_labels.csv')
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)

# Instantiate model
model = PoseRegressionNet()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# Loss & Optimizer
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)
# Out:
# /home/erythm/anaconda3/envs/6d/lib/python3.13/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/erythm/anaconda3/envs/6d/lib/python3.13/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
EPOCHS = 20

for epoch in range(EPOCHS):
    model.train()
    running_loss = 0.0

    for images, poses in dataloader:
        images = images.to(device)
        poses = poses.to(device)

        optimizer.zero_grad()

        outputs = model(images)           # [B, 12]
        loss = criterion(outputs, poses)  # MSE loss

        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    avg_loss = running_loss / len(dataloader)
    print(f"Epoch {epoch+1}/{EPOCHS} - Loss: {avg_loss:.6f}")
# Out:
# Epoch 1/20 - Loss: 0.168848
# Epoch 2/20 - Loss: 0.044755
# Epoch 3/20 - Loss: 0.022297
# Epoch 4/20 - Loss: 0.014712
# Epoch 5/20 - Loss: 0.013493
# Epoch 6/20 - Loss: 0.010694
# Epoch 7/20 - Loss: 0.008546
# Epoch 8/20 - Loss: 0.008115
# Epoch 9/20 - Loss: 0.008142
# Epoch 10/20 - Loss: 0.007708
# Epoch 11/20 - Loss: 0.006305
# Epoch 12/20 - Loss: 0.007238
# Epoch 13/20 - Loss: 0.007089
# Epoch 14/20 - Loss: 0.006736
# Epoch 15/20 - Loss: 0.005771
# Epoch 16/20 - Loss: 0.005289
# Epoch 17/20 - Loss: 0.005062
# Epoch 18/20 - Loss: 0.005174
# Epoch 19/20 - Loss: 0.005072
# Epoch 20/20 - Loss: 0.004782

# %%
torch.save(model.state_dict(), 'pose_regression_model.pth')
